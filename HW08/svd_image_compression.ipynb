# %%
# %%capture
# !apt-get update
# !apt-get install cm-super texlive-latex-extra texlive-fonts-recommended dvipng -y
# !git clone https://github.com/Ryan-M-Smith/CS315.git

# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os

plt.rcParams["figure.figsize"] = [16, 8]  # Set the output size
plt.rcParams["text.usetex"] = True        # Renter LaTex in plot titles

# %%
A = imread("CS315/HW08/landscape.jpg")
X = np.mean(A, -1);
SAVE = True
WIDTH, HEIGHT, _ = A.shape

# %%
img = plt.imshow(X)
img.set_cmap("gray")
plt.axis("off")
plt.show()

# %%
U, S, VT = np.linalg.svd(X, full_matrices=False)
S = np.diag(S)

# %%
for k in range(70, 110, 10):
  x_approx = U[:, :k] @ S[0:k,:k] @ VT[:k,:]
  plt.figure(1)
  img = plt.imshow(x_approx)
  img.set_cmap("gray")
  plt.axis("off")
  plt.title(rf"$k = {k}$")

  if SAVE:
    plt.savefig(f"grayscale{WIDTH}x{HEIGHT}k{k}.jpg")

  plt.show()
